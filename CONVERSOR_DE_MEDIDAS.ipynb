# %% [markdown]
# <a href="https://colab.research.google.com/github/samucale/CURSO.PYTHON.PROF.GUSTAVO-GUANABARA/blob/main/CONVERSOR_DE_MEDIDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CONVERSOR DE MEDIDAS**

# %%
m = float(input('uma distancia em metros '))
cm = m * 100
mm = m * 1000
print ('A medida de {} corresponde a {}cm e {}mm'.format (m,cm,mm))
# Out:
# uma distancia em metros 3
# A medida de 3.0 corresponde a 300.0cm e 3000.0mm
