# %% [markdown]
# <a href="https://colab.research.google.com/github/samucale/CURSO.PYTHON.PROF.GUSTAVO-GUANABARA/blob/main/M%C3%89DIA_DO_ALUNO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MEDIA DO ALUNO**

# %%
n1= float (input('primeira nota:'))
n2= float (input('segunda nota :'))
média  = (n1 + n2)/2
print ('A media entre {} e {} é igual a {} '.format (n1,n2,média))
# Out:
# primeira nota:5
# segunda nota :6
# A media entre 5.0 e 6.0 é igual a 5.5
