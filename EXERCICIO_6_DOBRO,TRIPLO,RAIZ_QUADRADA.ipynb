# %% [markdown]
# <a href="https://colab.research.google.com/github/samucale/CURSO.PYTHON.PROF.GUSTAVO-GUANABARA/blob/main/EXERCICIO_6_DOBRO%2CTRIPLO%2CRAIZ_QUADRADA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   **EXERCICIO 6 - DOBRO,TRIPLO,RAIZ QUADRADA**

# %%
n= int(input('digite um numero : '))
d = n * 2 
t = n * 3
r = n ** (1/2)
print ('o dobro de {} vale {}'.format (n,d))
print ('o triplo de {} vale {}'.format (n,t))
print ('A raiz quadrada de {} vale {}'.format (n,r))
# Out:
# digite um numero : 1
# o dobro de 1 vale 2
# o triplo de 1 vale 3
# A raiz quadrada de 1 vale 1.0
